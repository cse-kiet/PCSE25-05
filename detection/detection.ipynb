# %%
# %ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is 9E47-4E30
#
#  Directory of d:\FINAL ISL DATASET MAJOR\detection
#
# 02-03-2025  05:51    <DIR>          .
# 02-03-2025  06:27    <DIR>          ..
# 02-03-2025  05:49    <DIR>          ALL_IMAGES_ONCE
# 02-03-2025  05:53             8,804 detection.ipynb
# 02-03-2025  02:49            78,610 WIN_20250302_02_49_56_Pro.jpg
# 02-03-2025  00:08    <DIR>          yolov9
# 01-03-2025  23:58       122,470,234 yolov9c.pt
# 02-03-2025  00:00       122,470,234 yolov9e.pt
#                4 File(s)    245,027,882 bytes
#                4 Dir(s)  59,796,447,232 bytes free

# %%
# !nvidia-smi
# Out:
# Thu Mar 13 23:23:29 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 572.47                 Driver Version: 572.47         CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1650      WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   48C    P8              5W /   50W |       0MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/WongKinYiu/yolov9.git
# Out:
# fatal: destination path 'yolov9' already exists and is not an empty directory.

# %%
cd yolov9
# Out:
# d:\FINAL ISL DATASET MAJOR\detection\yolov9

# %%
import subprocess
import time

start_time = time.time()
subprocess.run(["python", "detect_dual.py","--weights", "../yolov9c.pt", "--source", "../WIN_20250302_02_49_56_Pro.jpg","--device","0"])  # Adjust arguments as needed
end_time = time.time()

print(f"Total Execution Time: {(end_time - start_time) * 1000:.2f} ms")
# Out:
# Total Execution Time: 7331.02 ms

# %%
import subprocess
import time

start_time = time.time()
subprocess.run(["python", "detect_dual.py","--weights", "../yolov9e.pt", "--source", "../WIN_20250302_02_49_56_Pro.jpg","--device","0"])  # Adjust arguments as needed
end_time = time.time()

print(f"Total Execution Time: {(end_time - start_time) * 1000:.2f} ms")
# Out:
# Total Execution Time: 6792.26 ms

# %%
# !python detect_dual.py --weights ../yolov9e.pt  --source 0 --device 0
# Out:
# ^C
# YOLOv9s summary (fused): 504 layers, 6,207,193 parameters, 0 gradients, 22.1 GFLOPs
# detect: weights=['../100100.pt'], source=0, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'D:\FINAL': No such file or directory
# YOLO  2025-3-2 Python-3.10.4 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
#
# 1/1: 0...  Success (inf frames 640x480 at 30.00 FPS)
#
# 0: 480x640 (no detections), 980.8ms
# 0: 480x640 (no detections), 20.8ms
# 0: 480x640 (no detections), 35.3ms
# 0: 480x640 (no detections), 35.0ms
# 0: 480x640 (no detections), 18.7ms
# 0: 480x640 (no detections), 22.0ms
# ...
